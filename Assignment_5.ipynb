# %% [markdown]
# Assignment 5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

# %% [markdown]
# i. Sum of all elements\
# ii. Sum of all elements row-wise\
# iii. Sum of all elements column-wise

# %%
all_sum = np.sum(gfg)

row_sum = np.sum(gfg, axis = 1)

column_sum = np.sum(gfg, axis = 0)

print("Sum of all elements:", all_sum)
print("Row-wise sum:\n", row_sum)
print("Column-wise sum:", column_sum)
# Out:
# Sum of all elements: 45
# Row-wise sum:
#  [[14]
#  [16]
#  [15]]
# Column-wise sum: [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])

# %% [markdown]
# i. Sorted array\
# ii. Indices of sorted array\
# iii. 4 smallest elements\
# iv. 5 largest elements

# %%
sorted_array = np.sort(array)

sorted_indices = np.argsort(array)

four_smallest = np.sort(array)[:4]

five_largest = np.sort(array[-5:])

print("Sorted Array:", sorted_array)
print("Indices of Sorted Array:", sorted_indices)
print("4 Smallest Elements:", four_smallest)
print("5 Largest Elements:", five_largest)
# Out:
# Sorted Array: [ 10  16  16  52  54  62 453]
# Indices of Sorted Array: [0 3 4 1 5 2 6]
# 4 Smallest Elements: [10 16 16 52]
# 5 Largest Elements: [ 16  16  54  62 453]

# %% [markdown]
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find

# %%
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

# %% [markdown]
# i. Integer elements only\
# ii. Float elements only

# %%
int_only = array[array == array.astype(int)]

float_only = array[array == array.astype(float)]

print("Integet only elements are:", int_only)
print("Float only elements are:", float_only)
# Out:
# Integet only elements are: [1. 2. 3. 2.]
# Float only elements are: [1.  1.2 2.2 2.  3.  2. ]

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.\
# a) Generate your unique sales dataset:\
# + Take the sum of the ASCII values of the initials of your first and last\
# name. Call this value X. (If your initials are A B → ASCII sum = 65 + 66 = 131 → sales = [131, 181, 231, 281, 331].)
# + Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].

# %%
def findAsciiSum(name):
    return sum(ord(char) for char in name.upper())

## X = ord("M") + ord("S")

X = findAsciiSum("MS")

sales = np.array([X, X + 50, X + 100, X + 150, X + 200])
print("Sales Data:", sales)
# Out:
# Sales Data: [160 210 260 310 360]

# %% [markdown]
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
# + Use broadcasting to apply this tax rate to each sales value.

# %%
tax_rate = ((X % 5) + 5)/ 100

taxed_sales = sales * (1 - tax_rate)
print("Sales after tax deduction:", taxed_sales)
# Out:
# Sales after tax deduction: [152.  199.5 247.  294.5 342. ]

# %% [markdown]
# c) Adjust sales based on discount:
# + If sales < X+100, apply a 5% discount.
# + If sales >= X+100, apply a 10% discount.

# %%
discounted_sales = np.where(sales < X + 100, sales * 0.95, sales * 0.90)
print("Discounted sales:", discounted_sales)
# Out:
# Discounted sales: [152.  199.5 234.  279.  324. ]

# %% [markdown]
# d) Expand sales data for multiple weeks:
# + Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
# + Increase sales by 2% per week using element-wise broadcasting.

# %%
sales_matrix = np.tile(sales, (3, 1))
weekly_increase = np.array([1.00, 1.02, 1.04]).reshape(3,1)
adjusted_sales = sales_matrix * weekly_increase

print("Weekly Sales Matrix:", adjusted_sales)
# Out:
# Weekly Sales Matrix: [[160.  210.  260.  310.  360. ]
#  [163.2 214.2 265.2 316.2 367.2]
#  [166.4 218.4 270.4 322.4 374.4]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
# + Y = x2
# + Y = sin(x)
# + Y = ex
# + Y = log(|x| + 1)\
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
x = np.linspace(-10, 10, 100)

y1 = x ** 2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log10(np.abs(x) + 1)

plt.figure(figsize = (10, 6))

plt.plot(x, y1, label = "Y = X^2")

plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x, y2, label = "Y = sin(X)")

plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x, y3, label = "Y = e^X")

plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x, y4, label = "Y = log(|X| + 1)")

plt.legend()
plt.grid(True)
plt.show()
